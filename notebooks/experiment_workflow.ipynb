# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
os.chdir(ROOT)
sys.path.insert(0, str(ROOT / 'src'))

# %%
import generation as gen

# %% [markdown]
# - $x_{ij} = 1\ or\ 0$
# - identical $B_i$ and $R_j$
# - $ \min_j R_j > 1 $

# %%
# feasible and connected and resilient
# input - N, T, B, R
# output - H_f
paras = {
    'N': 100,
    'T': 100,
    'B': 5,
    'R': 3
}
H = gen.gene_fcr_drop12(**paras)
gen.H_deg_edge_info(H)
# gen.gene_fcr(**paras)

# %%
# # persistence (1) - ability to maintain feasibility (1) -> ana_11
# # input - H, R, p_interval, runstep
# # output - number of unfeasible tasks at each (p, i)
# paras = {
#     'H': H,
#     'R': paras['R'],
#     'p_interval': (0.3, 300), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 500 # the number of realizations at each p
# }
# results = gen.ana_11(**paras)

# %%
# # persistence (1) - ability to maintain connectivity (2) -> ana_12
# # input - H, p_interval, runstep
# # output - number of connected components at each (p, i)
# paras = {
#     'H': H,
#     'p_interval': (0.3, 300), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 100 # the number of realizations at each p
# }
# results = gen.ana_12(**paras)

# %%
# # recoverability (2) - the ease with which disrupted tasks can be restored -> ana_2
# paras = {
#     'H': H,
#     'B': paras['B'],
#     'R': paras['R'],
#     'p_interval': (0.2, 20), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 50 # the number of realizations at each p
# }
# results = gen.ana_2(**paras)

# %% [markdown]
# ### Method validation

# %%
# # APS collaboration datesets 
# paras = {
#     'compare_types': ['ana_12'], # ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 100 # the number of realizations at each p
# }
# gen.compare_aps(**paras)

# %% [markdown]
# ### Other hypergraph generation methods

# %%
# # ER
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 5,
#     'R': 3,
#     'compare_types': ['ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 500 # the number of realizations at each p
# }
# gen.compare_er(**paras)

# %%
# # BA
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 4,
#     'R': 3,
#     'compare_types': ['ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 1000 # the number of realizations at each p
# }
# gen.compare_ba(**paras)

# %%
# # BA and ER
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 3,
#     'R': 3,
#     'compare_types': ['ana_11', 'ana_12', 'ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 1000 # the number of realizations at each p
# }
# gen.compare_erba(**paras)

# %% [markdown]
# ### Other search methods

# %%
# # SA
# paras = {
#     'N': 50,
#     'T': 50,
#     'B': 6,
#     'R': 3,
#     'compare_types': ['ana_11', 'ana_12', 'ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 1000 # the number of realizations at each p
# }
# gen.compare_sa(**paras)

# %%
# mu_2-guided SA
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 4,
#     'R': 3,
#     'compare_types': ['ana_11'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 1000 # the number of realizations at each p
# }
# gen.mu2_sa(**paras)

# %%
# greedy repair
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 4,
#     'R': 3,
#     'compare_types': ['ana_11', 'ana_12', 'ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 1000 # the number of realizations at each p
# }
# gen.run_greedy_repair(**paras)

# %% [markdown]
# ### diameter and algebraic connectivity

# %%
# # node\edge diameter and algebraic connectivity
# value = 50
# paras = [
#         {'N': value, 'T': value, 'B': 3, 'R': 3},
#         {'N': value, 'T': value, 'B': 4, 'R': 3},
#         {'N': value, 'T': value, 'B': 5, 'R': 3},
#         {'N': value, 'T': value, 'B': 6, 'R': 3}
#     ]

# gen.run_save(paras, value)

# %% [markdown]
# ### Runtime

# %%
# paras = {
#     'N': 500,
#     'T': 500,
#     'B': 6,
#     'R': 3
# }
# gen.get_runtime(**paras)

# %% [markdown]
# ### the star results of other size

# %%
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 6,
#     'R': 3,
#     'compare_types': ['ana_11', 'ana_12', 'ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 200), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 1000 # the number of realizations at each p
# }
# gen.single_star_results(**paras)

# %% [markdown]
# ### ablation experiment

# %%
# # # H_drop1
# paras = {
#     'N': 100,
#     'T': 100,
#     'B': 6,
#     'R': 3,
#     'compare_types': ['ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 100), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 10 # the number of realizations at each p
# }
# gen.run_ablation_drop1(**paras)
# gen.run_ablation_drop2(**paras)
# gen.run_ablation_drop12(**paras)

# %% [markdown]
# ### sensitivity analysis

# %%
# # R 2 3 4 5
# # B 3 4 5 6
# paras = {
#     'N': 100,
#     'T': 100,
#     'Bs': [3, 4, 5, 6],
#     'Rs': [2, 3, 4, 5]
#     'compare_types': ['ana_11', 'ana_12', 'ana_2'], # ana_11 ana_12  ana_2
#     'p_interval': (0.4, 100), # (stop, N), an interval [0, stop] with N equidistant values, length=N+1
#     'runstep': 10 # the number of realizations at each p
# }

# gen.sensi_r(**paras)
